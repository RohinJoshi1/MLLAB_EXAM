# %% [markdown]
# Supervised Learning Algorithms - Multiple Linear Regression (Multivariate):
#  Consider any dataset from UCI repository. Create Multiple Linear Regression models using the training data set. Predict the scores on the test data and find the error in prediction (E.g. RMSE, MAE, LSE).  Include appropriate code snippets to visualize the model. Use Sub-Plots Interpret the result. Write the Inference.

# %%
import pandas as pd
import numpy as np 
import seaborn as sb
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("../datasets/advertising.csv")

# %%
df.head()
# Out:
#    Unnamed: 0     TV  radio  newspaper  sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9

# %%
df.drop(columns=['Unnamed: 0'],inplace=True)

# %%
df
# Out:
#         TV  radio  newspaper  sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3    9.3
# 3    151.5   41.3       58.5   18.5
# 4    180.8   10.8       58.4   12.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1    9.7
# 197  177.0    9.3        6.4   12.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   13.4
#
# [200 rows x 4 columns]

# %%
x = df.drop(columns=['sales'])
y = df['sales']

# %%
x
# Out:
#         TV  radio  newspaper
# 0    230.1   37.8       69.2
# 1     44.5   39.3       45.1
# 2     17.2   45.9       69.3
# 3    151.5   41.3       58.5
# 4    180.8   10.8       58.4
# ..     ...    ...        ...
# 195   38.2    3.7       13.8
# 196   94.2    4.9        8.1
# 197  177.0    9.3        6.4
# 198  283.6   42.0       66.2
# 199  232.1    8.6        8.7
#
# [200 rows x 3 columns]

# %%
y
# Out:
# 0      22.1
# 1      10.4
# 2       9.3
# 3      18.5
# 4      12.9
#        ...
# 195     7.6
# 196     9.7
# 197    12.8
# 198    25.5
# 199    13.4
# Name: sales, Length: 200, dtype: float64

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn import metrics

# %%
model = LinearRegression()

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,random_state=True,test_size=0.2)

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test)

# %%
print(model.coef_)
# Out:
# [0.0468431  0.17854434 0.00258619]

# %%
print(model.intercept_)
# Out:
# 2.907947020816435

# %%
sb.pairplot(df,x_vars=['TV','radio','newspaper'],y_vars='sales',height=7,kind='reg')

# %%
model.score(x_test,y_test)
# Out:
# 0.8927605914615386

# %%
# accuracy=metrics.accuracy_score(y_test,y_pred)
y_test.shape == y_pred.shape
# Out:
# True

# %%
#RMS, MSE, MAS
print(metrics.mean_absolute_error(y_test,y_pred))
mse = metrics.mean_squared_error(y_test,y_pred)
print(mse)
print(np.sqrt(mse))
# Out:
# 1.0402154012924707
# 1.9918855518287848
# 1.4113417558581567
